# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("G:\DataScience_Projects\Fourth_Project\Insurance_Premium\insurance.csv")

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df.iloc[:,1] = label.fit_transform(df.iloc[:,1])
df.iloc[:,5] = label.fit_transform(df.iloc[:,5])
df.iloc[:,4] = label.fit_transform(df.iloc[:,4])

# %%
sns.pairplot(df)

# %%
X = df[['bmi','age','smoker','children']]
Y = df['expenses']

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
X_train,X_test,y_train,y_test = sklearn.model_selection.train_test_split(X,Y,test_size=0.25)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
regressor = DecisionTreeRegressor(random_state=0)
#cross_val_score(regressor, X_train, y_train, cv=10)
regressor.fit(X_train, y_train)
y_predict = regressor.predict(X_test)
mse_dt = mean_squared_error(y_test,y_predict,squared=False)
print(mse_dt)
# Out:
# 6781.574741325286

# %%
import xgboost as xg
from sklearn.model_selection import cross_val_score
xgb_r = xg.XGBRegressor()
#cross_val_score(regressor, X_train, y_train, cv=10)
xgb_r.fit(X_train, y_train)
y_predict = xgb_r.predict(X_test)
mse_xg = mean_squared_error(y_test,y_predict,squared=False)
print(mse_xg)
# Out:
# 5492.03672582162

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test,y_predict)
r2_score
# Out:
# 0.7972740535091636

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_train,regressor.predict(X_train))
r2_score
# Out:
# 0.996587253565408

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
#cross_val_score(regressor, X_train, y_train, cv=10)
regressor.fit(X_train, y_train)
y_predict = regressor.predict(X_test)
mse_dt = mean_squared_error(y_test,y_predict,squared=False)
print(mse_dt)
# Out:
# 5852.724940801249

# %%
import pickle
pickle.dump(regressor, open('model.pkl','wb'))
model = pickle.load(open('model.pkl','rb'))

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
lazy_reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = lazy_reg.fit(X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-e832210235f4> in <module>
#       4 from sklearn.utils import shuffle
#       5 lazy_reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
# ----> 6 models, predictions = lazy_reg.fit(X_train, X_test, y_train, y_test)
#
# c:\ProgramData\Anaconda3\lib\site-packages\lazypredict\Supervised.py in fit(self, X_train, X_test, y_train, y_test)
#     562
#     563         categorical_low, categorical_high = get_card_split(
# --> 564             X_train, categorical_features
#     565         )
#     566
#
# c:\ProgramData\Anaconda3\lib\site-packages\lazypredict\Supervised.py in get_card_split(df, cols, n)
#     131     """
#     132     cond = df[cols].nunique() > n
# --> 133     card_high = cols[cond]
#     134     card_low = cols[~cond]
#     135     return card_low, card_high
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3967
#    3968         key = com.values_from_object(key)
# -> 3969         result = getitem(key)
#    3970         if not is_scalar(result):
#    3971             return promote(result)
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
models
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-181ea416d56e> in <module>
# ----> 1 models
#
# NameError: name 'models' is not defined
